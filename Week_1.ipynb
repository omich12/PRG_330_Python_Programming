# %%
print("Welcome to Data Analysis with Python Course")
# Out:
# Welcome to Data Analysis with Python Course

# %%
print("Hello, everyone")
# Out:
# Hello, everyone

# %%
name = "Omi Chaurasia"
print(name)
# Out:
# Omi Chaurasia

# %%
course = "PRG 330 Python Programming with Data"
print(course)
# Out:
# PRG 330 Python Programming with Data
